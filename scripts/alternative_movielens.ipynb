# %%
import string

import pandas as pd
import numpy as np
from nltk import word_tokenize, wordpunct_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from rake_nltk import Rake
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from unidecode import unidecode

# %% [markdown]
# ### Tratamento dos dados

# %%
movies_df = pd.read_csv('../data/movies.csv')
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
overview_df = pd.read_csv('../data/overviews.csv')
overview_df.head()
# Out:
#    movieId  tmdbId                                           overview
# 0        1     862  Led by Woody, Andy's toys live happily in his ...
# 1        2    8844  When siblings Judy and Peter discover an encha...
# 2        3   15602  A family wedding reignites the ancient feud be...
# 3        4   31357  Cheated on, mistreated and stepped on, the wom...
# 4        5   11862  Just when George Banks has recovered from his ...

# %%
ratings_df = pd.read_csv('../data/ratings.csv')
ratings_df.drop(columns=['timestamp'], inplace=True)
ratings_df.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
ratings_df.shape
# Out:
# (100836, 3)

# %%
movies_df.shape
# Out:
# (9742, 3)

# %%
overview_df.shape
# Out:
# (9742, 3)

# %%
ratings_df.isna().sum()
# Out:
# userId     0
# movieId    0
# rating     0
# dtype: int64

# %%
movies_df.isna().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
overview_df.isna().sum()
# Out:
# movieId       0
# tmdbId        0
# overview    117
# dtype: int64

# %%
list_movies_missing_overview = list(overview_df[overview_df.overview.isna()]['movieId'])

# %%
overview_df.dropna(inplace=True)
overview_df.isna().sum()
# Out:
# movieId     0
# tmdbId      0
# overview    0
# dtype: int64

# %%
# remove ratings dos filmes 'dropados'

ratings_df = ratings_df[~ratings_df.movieId.isin(list_movies_missing_overview)]
ratings_df.reset_index(inplace=True)
ratings_df.drop(columns=['index'], inplace=True)

# %%
#remove filmes 'dropados' do df de filmes

movies_df = movies_df[~movies_df.movieId.isin(list_movies_missing_overview)]

# %%
movies_df.shape
# Out:
# (9625, 3)

# %%
overview_df.shape
# Out:
# (9625, 3)

# %%
ratings_df.shape
# Out:
# (100525, 3)

# %%
ratings_df
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100520     610   166534     4.0
# 100521     610   168248     5.0
# 100522     610   168250     5.0
# 100523     610   168252     5.0
# 100524     610   170875     3.0
#
# [100525 rows x 3 columns]

# %%
experiment_df = movies_df.set_index('movieId').join(overview_df.set_index('movieId'), how='left')

# %%
experiment_df.reset_index(inplace=True)
experiment_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  tmdbId  \
# 0  Adventure|Animation|Children|Comedy|Fantasy     862
# 1                   Adventure|Children|Fantasy    8844
# 2                               Comedy|Romance   15602
# 3                         Comedy|Drama|Romance   31357
# 4                                       Comedy   11862
#
#                                             overview
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...

# %%
experiment_df.replace('(no genres listed)', '', inplace=True)

# %%
# colocando os gêneros em uma lista de palavras
experiment_df['genres'] = experiment_df['genres'].map(lambda x: x.lower().split('|'))

# %%
experiment_df.drop(columns=['tmdbId'], inplace=True)
experiment_df.set_index('movieId', inplace=True)

# %%
experiment_df.head()
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                                     genres  \
# movieId
# 1        [adventure, animation, children, comedy, fantasy]
# 2                           [adventure, children, fantasy]
# 3                                        [comedy, romance]
# 4                                 [comedy, drama, romance]
# 5                                                 [comedy]
#
#                                                   overview
# movieId
# 1        Led by Woody, Andy's toys live happily in his ...
# 2        When siblings Judy and Peter discover an encha...
# 3        A family wedding reignites the ancient feud be...
# 4        Cheated on, mistreated and stepped on, the wom...
# 5        Just when George Banks has recovered from his ...

# %%
# filtrar ratings maiores ou iguais a 4.0
ratings_df = ratings_df[ratings_df.rating >= 4.0]
ratings_df
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100519     610   166528     4.0
# 100520     610   166534     4.0
# 100521     610   168248     5.0
# 100522     610   168250     5.0
# 100523     610   168252     5.0
#
# [48388 rows x 3 columns]

# %%
# Filtrar usuários que deram menos do que 20 ratings
users = set(ratings_df.userId.to_list())

users_to_remove = []

for user in users:
    if len(ratings_df[ratings_df.userId == user]) < 20:
        users_to_remove.append(user)

users_to_remove
ratings_df = ratings_df[~ratings_df.userId.isin(users_to_remove)]

# %%
users = set(ratings_df.userId.to_list())
len(users)
# Out:
# 465

# %%
experiment_df
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                                     genres  \
# movieId
# 1        [adventure, animation, children, comedy, fantasy]
# 2                           [adventure, children, fantasy]
# 3                                        [comedy, romance]
# 4                                 [comedy, drama, romance]
# 5                                                 [comedy]
# ...                                                    ...
# 193581                [action, animation, comedy, fantasy]
# 193583                        [animation, comedy, fantasy]
# 193585                                             [drama]
# 193587                                 [action, animation]
# 193609                                            [comedy]
#
#                                                   overview
# movieId
# 1        Led by Woody, Andy's toys live happily in his ...
# 2        When siblings Judy and Peter discover an encha...
# 3        A family wedding reignites the ancient feud be...
# 4        Cheated on, mistreated and stepped on, the wom...
# 5        Just when George Banks has recovered from his ...
# ...                                                    ...
# 193581   Ciel learns of a Aurora Society, that is rumor...
# 193583   In ancient Disboard, Riku is an angry, young w...
# 193585   A woman deals with the toxic water scandal in ...
# 193587   A large scale catastrophe is occurring across ...
# 193609   Outrageous, misogynistic and vulgar-to-the-max...
#
# [9625 rows x 3 columns]

# %%
ratings_df
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100519     610   166528     4.0
# 100520     610   166534     4.0
# 100521     610   168248     5.0
# 100522     610   168250     5.0
# 100523     610   168252     5.0
#
# [46509 rows x 3 columns]

# %% [markdown]
# ### Iniciando o processo de recomendação

# %% [markdown]
# #### Definindo funções

# %%
def nlp_pre_process(corpus, stop_words_remv = True, lemmatization = True, stemmization = True):
    
    corpus = corpus.lower()
    corpus = unidecode(corpus) # remove non-ascii characters

    punctuations = list(string.punctuation)
    punctuations.append('...')
    
    corpus = " ".join([token for token in wordpunct_tokenize(corpus) if token not in punctuations])
    
    if (stop_words_remv):
        stopset = stopwords.words('english')
        corpus = " ".join([token for token in word_tokenize(corpus) if token not in stopset])

    if (lemmatization):
        lemmatizer = WordNetLemmatizer()
        corpus = " ".join([lemmatizer.lemmatize(token) for token in word_tokenize(corpus)])
    
    if (stemmization):
        stemmer = PorterStemmer()
        corpus = " ".join([stemmer.stem(token) for token in word_tokenize(corpus)])
        
    return corpus

# %%
def create_bag_of_words(df):
    df['bag_of_words'] = ''
    columns = df.columns

    for index, row in df.iterrows():
        words = ''
        for col in columns:
            if col != 'title':
                words = words + ' '.join(row[col])+ ' '
        row['bag_of_words'] = words
        
    df.drop(columns = [col for col in df.columns if col != 'bag_of_words' and col != 'title'], inplace = True)

    return df

# %%
def pre_process(movies_df, stopwords_removal=True, lemmatization=True, stemmization=True):
    df = movies_df.copy()
    
    df['overview'] = df['overview'].apply(nlp_pre_process, args=(stopwords_removal, lemmatization, stemmization))

    df['overview'] = df['overview'].apply(str.split)

    df = create_bag_of_words(df)

    return df

# %%
def recommender(movies_interacteds, movies_to_recomend, cosine_similarity):

    similaritys = cosine_similarity[movies_to_recomend][cosine_similarity.index.isin(movies_interacteds)]

    average_similarity = similaritys.mean()

    top_10_movies = average_similarity.sort_values(ascending = False).iloc[0:10].index.to_list()

    return top_10_movies

# %%
def generate_similarity_matrix(df):
    count = TfidfVectorizer()
    count_matrix = count.fit_transform(df['bag_of_words'])

    # gerando a matriz de similaridade de cosseno
    cosine_sim = cosine_similarity(count_matrix, count_matrix)

    return cosine_sim

# %%
def get_rr_from_list(relevance_array):
    relevance_list_size = len(relevance_array)
    if relevance_list_size == 0:
        return 0.0
    for i in range(relevance_list_size):
        if relevance_array[i]:
            return 1 / (i + 1)
    return 0.0

# %%
def get_ap_from_list(relevance_array):
    relevance_list_size = len(relevance_array)
    if relevance_list_size == 0:
        return 0.0
    hit_list = []
    relevant = 0
    for i in range(relevance_list_size):
        if relevance_array[i]:
            relevant += 1
        hit_list.append(relevant / (i + 1))
    ap = sum(hit_list)
    if ap > 0.0:
        return ap / relevance_list_size
    else:
        return 0.0

# %%
def get_recomendations(movies_df, profile, cosine_sim, frac, seed):
    
    train_items = profile.sample(frac=frac, random_state=seed)
    test_items = profile[~profile.movieId.isin(train_items.movieId)]

    movies_interacteds = train_items.sample(15).movieId.to_list()

    movies_to_recomend = test_items.sample(5).movieId.to_list() + movies_df.sample(20).index.to_list()

    movies_recomended = recommender(movies_interacteds, movies_to_recomend, cosine_sim)

    relevance = [True if movie in test_items.movieId.to_list() else False for movie in movies_recomended]

    return relevance

    # precision = relevance.count(True) / 10

    # average_precision = get_ap_from_list(relevance)

    # reciprocal_rank = get_rr_from_list(relevance)

    # return movies_recomended, precision, average_precision, reciprocal_rank

# %%
def evaluation_recommendation(movies_df, ratings_df, pre_process_tec, count=1, rating_threshold=4.0, frac=0.75, seed=15):

    stopwords, lemma, stemm = pre_process_tec
   
    movies_df = pre_process(movies_df, stopwords_removal=stopwords, lemmatization=lemma, stemmization=stemm)

    cosine_sim = pd.DataFrame(generate_similarity_matrix(movies_df), columns=movies_df.index.to_list(), index=movies_df.index.to_list())

    user_ids = set(list(ratings_df.userId))

    for user_id in user_ids:
        profile = ratings_df[ratings_df.userId == user_id]
        
        relevance = get_recomendations(movies_df, profile, cosine_sim, frac, seed)
        
        prc_10 = relevance.count(True) / 10
        ap_10 = get_ap_from_list(relevance)
        rr_10 = get_rr_from_list(relevance)

        relevance_5 = relevance[:5]
        prc_5 = relevance_5.count(True) / 5
        ap_5 = get_ap_from_list(relevance_5)
        rr_5 = get_rr_from_list(relevance_5)

        relevance_3 = relevance[:3]
        prc_3 = relevance_3.count(True) / 3
        ap_3 = get_ap_from_list(relevance_3)
        rr_3 = get_rr_from_list(relevance_3)

        try:
            with open(f'../result/recomendations_{count}.csv', 'a') as recomendations:
                recomendations.write(f'{user_id},"{prc_10}",{prc_5},{prc_3},{ap_10},{ap_5},{ap_3},{rr_10},{rr_5},{rr_3}\n')
        except Exception:
            print('Falha ao gravar as recomendações do id {}'.format(user_id))
            with open(f'../result/fails_{count}.csv', 'a') as fails:
                fails.write(f'{user_id},"{prc_10}",{prc_5},{prc_3},{ap_10},{ap_5},{ap_3},{rr_10},{rr_5},{rr_3}\n')
        else:
            print('Recomendações do id {} gravado.'.format(user_id))

# %%
combination_pre_process_techniques = [
    (1, (False, False, False)),
    (2, (False, False, True)),
    (3, (False, True, False)),
    (4, (False, True, True)),
    (5, (True, False, False)),
    (6, (True, False, True)),
    (7, (True, True, False)),
    (8, (True, True, True)),
]

# %%
for count, technique in combination_pre_process_techniques:
    evaluation_recommendation(experiment_df, ratings_df, technique, count)
# Out:
# Recomendações do id 1 gravado.
# Recomendações do id 4 gravado.
# Recomendações do id 5 gravado.
# Recomendações do id 6 gravado.
# Recomendações do id 7 gravado.
# Recomendações do id 8 gravado.
# Recomendações do id 9 gravado.
# Recomendações do id 10 gravado.
# Recomendações do id 11 gravado.
# Recomendações do id 12 gravado.
# Recomendações do id 14 gravado.
# Recomendações do id 15 gravado.
# Recomendações do id 16 gravado.
# Recomendações do id 17 gravado.
# Recomendações do id 18 gravado.
# Recomendações do id 19 gravado.
# Recomendações do id 20 gravado.
# Recomendações do id 21 gravado.
# Recomendações do id 22 gravado.
# Recomendações do id 23 gravado.
# Recomendações do id 24 gravado.
# Recomendações do id 25 gravado.
# Recomendações do id 27 gravado.
# Recomendações do id 28 gravado.
# Recomendações do id 29 gravado.
# Recomendações do id 30 gravado.
# Recomendações do id 31 gravado.
# Recomendações do id 32 gravado.
# Recomendações do id 33 gravado.
# Recomendações do id 34 gravado.
# Recomendações do id 38 gravado.
# Recomendações do id 39 gravado.
# Recomendações do id 40 gravado.
# Recomendações do id 41 gravado.
# Recomendações do id 42 gravado.
# Recomendações do id 43 gravado.
# Recomendações do id 44 gravado.
# Recomendações do id 45 gravado.
# Recomendações do id 46 gravado.
# Recomendações do id 47 gravado.
# Recomendações do id 48 gravado.
# Recomendações do id 49 gravado.
# Recomendações do id 50 gravado.
# Recomendações do id 51 gravado.
# Recomendações do id 52 gravado.
# Recomendações do id 53 gravado.
# Recomendações do id 56 gravado.
# Recomendações do id 57 gravado.
# Recomendações do id 58 gravado.
# Recomendações do id 59 gravado.
# Recomendações do id 61 gravado.
# Recomendações do id 62 gravado.
# Recomendações do id 63 gravado.
# Recomendações do id 64 gravado.
# Recomendações do id 65 gravado.
# Recomendações do id 66 gravado.
# Recomendações do id 67 gravado.
# Recomendações do id 68 gravado.
# Recomendações do id 69 gravado.
# Recomendações do id 70 gravado.
# Recomendações do id 71 gravado.
# Recomendações do id 72 gravado.
# Recomendações do id 73 gravado.
# Recomendações do id 74 gravado.
# Recomendações do id 75 gravado.
# Recomendações do id 76 gravado.
# Recomendações do id 78 gravado.
# Recomendações do id 79 gravado.
# Recomendações do id 80 gravado.
# Recomendações do id 82 gravado.
# Recomendações do id 83 gravado.
# Recomendações do id 84 gravado.
# Recomendações do id 85 gravado.
# Recomendações do id 86 gravado.
# Recomendações do id 88 gravado.
# Recomendações do id 89 gravado.
# Recomendações do id 90 gravado.
# Recomendações do id 91 gravado.
# Recomendações do id 93 gravado.
# Recomendações do id 95 gravado.
# Recomendações do id 96 gravado.
# Recomendações do id 97 gravado.
# Recomendações do id 98 gravado.
# Recomendações do id 99 gravado.
# Recomendações do id 100 gravado.
# Recomendações do id 101 gravado.
# Recomendações do id 102 gravado.
# Recomendações do id 103 gravado.
# Recomendações do id 104 gravado.
# Recomendações do id 105 gravado.
# Recomendações do id 106 gravado.
# Recomendações do id 107 gravado.
# Recomendações do id 108 gravado.
# Recomendações do id 109 gravado.
# Recomendações do id 110 gravado.
# Recomendações do id 111 gravado.
# Recomendações do id 112 gravado.
# Recomendações do id 113 gravado.
# Recomendações do id 115 gravado.
# Recomendações do id 116 gravado.
# Recomendações do id 117 gravado.
# Recomendações do id 119 gravado.
# Recomendações do id 121 gravado.
# Recomendações do id 122 gravado.
# Recomendações do id 123 gravado.
# Recomendações do id 124 gravado.
# Recomendações do id 125 gravado.
# Recomendações do id 128 gravado.
# Recomendações do id 129 gravado.
# Recomendações do id 131 gravado.
# Recomendações do id 132 gravado.
# Recomendações do id 135 gravado.
# Recomendações do id 136 gravado.
# Recomendações do id 137 gravado.
# Recomendações do id 140 gravado.
# Recomendações do id 141 gravado.
# Recomendações do id 142 gravado.
# Recomendações do id 143 gravado.
# Recomendações do id 144 gravado.
# Recomendações do id 148 gravado.
# Recomendações do id 151 gravado.
# Recomendações do id 152 gravado.
# Recomendações do id 153 gravado.
# Recomendações do id 154 gravado.
# Recomendações do id 155 gravado.
# Recomendações do id 156 gravado.
# Recomendações do id 159 gravado.
# Recomendações do id 160 gravado.
# Recomendações do id 161 gravado.
# Recomendações do id 162 gravado.
# Recomendações do id 164 gravado.
# Recomendações do id 165 gravado.
# Recomendações do id 166 gravado.
# Recomendações do id 167 gravado.
# Recomendações do id 168 gravado.
# Recomendações do id 169 gravado.
# Recomendações do id 171 gravado.
# Recomendações do id 174 gravado.
# Recomendações do id 176 gravado.
# Recomendações do id 177 gravado.
# Recomendações do id 178 gravado.
# Recomendações do id 179 gravado.
# Recomendações do id 181 gravado.
# Recomendações do id 182 gravado.
# Recomendações do id 183 gravado.
# Recomendações do id 184 gravado.
# Recomendações do id 185 gravado.
# Recomendações do id 186 gravado.
# Recomendações do id 187 gravado.
# Recomendações do id 188 gravado.
# Recomendações do id 190 gravado.
# Recomendações do id 191 gravado.
# Recomendações do id 193 gravado.
# Recomendações do id 195 gravado.
# Recomendações do id 197 gravado.
# Recomendações do id 198 gravado.
# Recomendações do id 199 gravado.
# Recomendações do id 200 gravado.
# Recomendações do id 201 gravado.
# Recomendações do id 202 gravado.
# Recomendações do id 203 gravado.
# Recomendações do id 204 gravado.
# Recomendações do id 209 gravado.
# Recomendações do id 210 gravado.
# Recomendações do id 211 gravado.
# Recomendações do id 212 gravado.
# Recomendações do id 213 gravado.
# Recomendações do id 215 gravado.
# Recomendações do id 216 gravado.
# Recomendações do id 217 gravado.
# Recomendações do id 219 gravado.
# Recomendações do id 220 gravado.
# Recomendações do id 221 gravado.
# Recomendações do id 222 gravado.
# Recomendações do id 223 gravado.
# Recomendações do id 224 gravado.
# Recomendações do id 225 gravado.
# Recomendações do id 226 gravado.
# Recomendações do id 227 gravado.
# Recomendações do id 229 gravado.
# Recomendações do id 230 gravado.
# Recomendações do id 232 gravado.
# Recomendações do id 233 gravado.
# Recomendações do id 234 gravado.
# Recomendações do id 235 gravado.
# Recomendações do id 236 gravado.
# Recomendações do id 238 gravado.
# Recomendações do id 239 gravado.
# Recomendações do id 240 gravado.
# Recomendações do id 241 gravado.
# Recomendações do id 243 gravado.
# Recomendações do id 244 gravado.
# Recomendações do id 246 gravado.
# Recomendações do id 247 gravado.
# Recomendações do id 248 gravado.
# Recomendações do id 249 gravado.
# Recomendações do id 250 gravado.
# Recomendações do id 251 gravado.
# Recomendações do id 252 gravado.
# Recomendações do id 253 gravado.
# Recomendações do id 254 gravado.
# Recomendações do id 256 gravado.
# Recomendações do id 260 gravado.
# Recomendações do id 261 gravado.
# Recomendações do id 263 gravado.
# Recomendações do id 264 gravado.
# Recomendações do id 265 gravado.
# Recomendações do id 266 gravado.
# Recomendações do id 267 gravado.
# Recomendações do id 268 gravado.
# Recomendações do id 273 gravado.
# Recomendações do id 274 gravado.
# Recomendações do id 275 gravado.
# Recomendações do id 276 gravado.
# Recomendações do id 279 gravado.
# Recomendações do id 280 gravado.
# Recomendações do id 282 gravado.
# Recomendações do id 284 gravado.
# Recomendações do id 285 gravado.
# Recomendações do id 286 gravado.
# Recomendações do id 287 gravado.
# Recomendações do id 288 gravado.
# Recomendações do id 290 gravado.
# Recomendações do id 291 gravado.
# Recomendações do id 292 gravado.
# Recomendações do id 294 gravado.
# Recomendações do id 295 gravado.
# Recomendações do id 296 gravado.
# Recomendações do id 297 gravado.
# Recomendações do id 298 gravado.
# Recomendações do id 300 gravado.
# Recomendações do id 301 gravado.
# Recomendações do id 302 gravado.
# Recomendações do id 303 gravado.
# Recomendações do id 304 gravado.
# Recomendações do id 305 gravado.
# Recomendações do id 306 gravado.
# Recomendações do id 307 gravado.
# Recomendações do id 308 gravado.
# Recomendações do id 309 gravado.
# Recomendações do id 310 gravado.
# Recomendações do id 312 gravado.
# Recomendações do id 313 gravado.
# Recomendações do id 314 gravado.
# Recomendações do id 317 gravado.
# Recomendações do id 318 gravado.
# Recomendações do id 319 gravado.
# Recomendações do id 321 gravado.
# Recomendações do id 322 gravado.
# Recomendações do id 323 gravado.
# Recomendações do id 325 gravado.
# Recomendações do id 326 gravado.
# Recomendações do id 327 gravado.
# Recomendações do id 328 gravado.
# Recomendações do id 330 gravado.
# Recomendações do id 331 gravado.
# Recomendações do id 332 gravado.
# Recomendações do id 334 gravado.
# Recomendações do id 336 gravado.
# Recomendações do id 337 gravado.
# Recomendações do id 339 gravado.
# Recomendações do id 340 gravado.
# Recomendações do id 341 gravado.
# Recomendações do id 343 gravado.
# Recomendações do id 344 gravado.
# Recomendações do id 345 gravado.
# Recomendações do id 346 gravado.
# Recomendações do id 347 gravado.
# Recomendações do id 348 gravado.
# Recomendações do id 349 gravado.
# Recomendações do id 351 gravado.
# Recomendações do id 352 gravado.
# Recomendações do id 353 gravado.
# Recomendações do id 354 gravado.
# Recomendações do id 356 gravado.
# Recomendações do id 357 gravado.
# Recomendações do id 358 gravado.
# Recomendações do id 359 gravado.
# Recomendações do id 361 gravado.
# Recomendações do id 362 gravado.
# Recomendações do id 365 gravado.
# Recomendações do id 366 gravado.
# Recomendações do id 367 gravado.
# Recomendações do id 368 gravado.
# Recomendações do id 369 gravado.
# Recomendações do id 370 gravado.
# Recomendações do id 371 gravado.
# Recomendações do id 372 gravado.
# Recomendações do id 373 gravado.
# Recomendações do id 375 gravado.
# Recomendações do id 376 gravado.
# Recomendações do id 377 gravado.
# Recomendações do id 378 gravado.
# Recomendações do id 380 gravado.
# Recomendações do id 381 gravado.
# Recomendações do id 382 gravado.
# Recomendações do id 383 gravado.
# Recomendações do id 384 gravado.
# Recomendações do id 385 gravado.
# Recomendações do id 387 gravado.
# Recomendações do id 389 gravado.
# Recomendações do id 390 gravado.
# Recomendações do id 391 gravado.
# Recomendações do id 393 gravado.
# Recomendações do id 398 gravado.
# Recomendações do id 399 gravado.
# Recomendações do id 400 gravado.
# Recomendações do id 401 gravado.
# Recomendações do id 402 gravado.
# Recomendações do id 404 gravado.
# Recomendações do id 405 gravado.
# Recomendações do id 408 gravado.
# Recomendações do id 409 gravado.
# Recomendações do id 410 gravado.
# Recomendações do id 411 gravado.
# Recomendações do id 412 gravado.
# Recomendações do id 413 gravado.
# Recomendações do id 414 gravado.
# Recomendações do id 415 gravado.
# Recomendações do id 416 gravado.
# Recomendações do id 417 gravado.
# Recomendações do id 418 gravado.
# Recomendações do id 419 gravado.
# Recomendações do id 420 gravado.
# Recomendações do id 421 gravado.
# Recomendações do id 422 gravado.
# Recomendações do id 424 gravado.
# Recomendações do id 425 gravado.
# Recomendações do id 426 gravado.
# Recomendações do id 427 gravado.
# Recomendações do id 428 gravado.
# Recomendações do id 429 gravado.
# Recomendações do id 430 gravado.
# Recomendações do id 432 gravado.
# Recomendações do id 434 gravado.
# Recomendações do id 435 gravado.
# Recomendações do id 436 gravado.
# Recomendações do id 437 gravado.
# Recomendações do id 438 gravado.
# Recomendações do id 440 gravado.
# Recomendações do id 441 gravado.
# Recomendações do id 443 gravado.
# Recomendações do id 444 gravado.
# Recomendações do id 445 gravado.
# Recomendações do id 446 gravado.
# Recomendações do id 447 gravado.
# Recomendações do id 448 gravado.
# Recomendações do id 450 gravado.
# Recomendações do id 451 gravado.
# Recomendações do id 452 gravado.
# Recomendações do id 453 gravado.
# Recomendações do id 454 gravado.
# Recomendações do id 455 gravado.
# Recomendações do id 456 gravado.
# Recomendações do id 457 gravado.
# Recomendações do id 458 gravado.
# Recomendações do id 459 gravado.
# Recomendações do id 460 gravado.
# Recomendações do id 462 gravado.
# Recomendações do id 464 gravado.
# Recomendações do id 465 gravado.
# Recomendações do id 466 gravado.
# Recomendações do id 469 gravado.
# Recomendações do id 470 gravado.
# Recomendações do id 472 gravado.
# Recomendações do id 474 gravado.
# Recomendações do id 475 gravado.
# Recomendações do id 476 gravado.
# Recomendações do id 477 gravado.
# Recomendações do id 479 gravado.
# Recomendações do id 480 gravado.
# Recomendações do id 482 gravado.
# Recomendações do id 483 gravado.
# Recomendações do id 484 gravado.
# Recomendações do id 486 gravado.
# Recomendações do id 488 gravado.
# Recomendações do id 489 gravado.
# Recomendações do id 490 gravado.
# Recomendações do id 491 gravado.
# Recomendações do id 492 gravado.
# Recomendações do id 493 gravado.
# Recomendações do id 495 gravado.
# Recomendações do id 497 gravado.
# Recomendações do id 498 gravado.
# Recomendações do id 500 gravado.
# Recomendações do id 503 gravado.
# Recomendações do id 504 gravado.
# Recomendações do id 505 gravado.
# Recomendações do id 509 gravado.
# Recomendações do id 510 gravado.
# Recomendações do id 511 gravado.
# Recomendações do id 512 gravado.
# Recomendações do id 513 gravado.
# Recomendações do id 514 gravado.
# Recomendações do id 515 gravado.
# Recomendações do id 517 gravado.
# Recomendações do id 519 gravado.
# Recomendações do id 520 gravado.
# Recomendações do id 521 gravado.
# Recomendações do id 522 gravado.
# Recomendações do id 523 gravado.
# Recomendações do id 524 gravado.
# Recomendações do id 525 gravado.
# Recomendações do id 526 gravado.
# Recomendações do id 527 gravado.
# Recomendações do id 528 gravado.
# Recomendações do id 532 gravado.
# Recomendações do id 533 gravado.
# Recomendações do id 534 gravado.
# Recomendações do id 537 gravado.
# Recomendações do id 538 gravado.
# Recomendações do id 540 gravado.
# Recomendações do id 541 gravado.
# Recomendações do id 542 gravado.
# Recomendações do id 543 gravado.
# Recomendações do id 546 gravado.
# Recomendações do id 550 gravado.
# Recomendações do id 551 gravado.
# Recomendações do id 552 gravado.
# Recomendações do id 553 gravado.
# Recomendações do id 554 gravado.
# Recomendações do id 555 gravado.
# Recomendações do id 556 gravado.
# Recomendações do id 558 gravado.
# Recomendações do id 559 gravado.
# Recomendações do id 560 gravado.
# Recomendações do id 561 gravado.
# Recomendações do id 562 gravado.
# Recomendações do id 563 gravado.
# Recomendações do id 564 gravado.
# Recomendações do id 566 gravado.
# Recomendações do id 567 gravado.
# Recomendações do id 570 gravado.
# Recomendações do id 571 gravado.
# Recomendações do id 572 gravado.
# Recomendações do id 573 gravado.
# Recomendações do id 577 gravado.
# Recomendações do id 578 gravado.
# Recomendações do id 579 gravado.
# Recomendações do id 580 gravado.
# Recomendações do id 581 gravado.
# Recomendações do id 582 gravado.
# Recomendações do id 584 gravado.
# Recomendações do id 585 gravado.
# Recomendações do id 586 gravado.
# Recomendações do id 587 gravado.
# Recomendações do id 589 gravado.
# Recomendações do id 590 gravado.
# Recomendações do id 591 gravado.
# Recomendações do id 592 gravado.
# Recomendações do id 593 gravado.
# Recomendações do id 594 gravado.
# Recomendações do id 596 gravado.
# Recomendações do id 597 gravado.
# Recomendações do id 599 gravado.
# Recomendações do id 600 gravado.
# Recomendações do id 601 gravado.
# Recomendações do id 602 gravado.
# Recomendações do id 603 gravado.
# Recomendações do id 604 gravado.
# Recomendações do id 605 gravado.
# Recomendações do id 606 gravado.
# Recomendações do id 607 gravado.
# Recomendações do id 608 gravado.
# Recomendações do id 610 gravado.
# Recomendações do id 1 gravado.
# Recomendações do id 4 gravado.
# Recomendações do id 5 gravado.
# Recomendações do id 6 gravado.
# Recomendações do id 7 gravado.
# Recomendações do id 8 gravado.
# Recomendações do id 9 gravado.
# Recomendações do id 10 gravado.
# Recomendações do id 11 gravado.
# Recomendações do id 12 gravado.
# Recomendações do id 14 gravado.
# Recomendações do id 15 gravado.
# Recomendações do id 16 gravado.
# Recomendações do id 17 gravado.
# Recomendações do id 18 gravado.
# Recomendações do id 19 gravado.
# Recomendações do id 20 gravado.
# Recomendações do id 21 gravado.
# Recomendações do id 22 gravado.
# Recomendações do id 23 gravado.
# Recomendações do id 24 gravado.
# Recomendações do id 25 gravado.
# Recomendações do id 27 gravado.
# Recomendações do id 28 gravado.
# Recomendações do id 29 gravado.
# Recomendações do id 30 gravado.
# Recomendações do id 31 gravado.
# Recomendações do id 32 gravado.
# Recomendações do id 33 gravado.
# Recomendações do id 34 gravado.
# Recomendações do id 38 gravado.
# Recomendações do id 39 gravado.
# Recomendações do id 40 gravado.
# Recomendações do id 41 gravado.
# Recomendações do id 42 gravado.
# Recomendações do id 43 gravado.
# Recomendações do id 44 gravado.
# Recomendações do id 45 gravado.
# Recomendações do id 46 gravado.
# Recomendações do id 47 gravado.
# Recomendações do id 48 gravado.
# Recomendações do id 49 gravado.
# Recomendações do id 50 gravado.
# Recomendações do id 51 gravado.
# Recomendações do id 52 gravado.
# Recomendações do id 53 gravado.
# Recomendações do id 56 gravado.
# Recomendações do id 57 gravado.
# Recomendações do id 58 gravado.
# Recomendações do id 59 gravado.
# Recomendações do id 61 gravado.
# Recomendações do id 62 gravado.
# Recomendações do id 63 gravado.
# Recomendações do id 64 gravado.
# Recomendações do id 65 gravado.
# Recomendações do id 66 gravado.
# Recomendações do id 67 gravado.
# Recomendações do id 68 gravado.
# Recomendações do id 69 gravado.
# Recomendações do id 70 gravado.
# Recomendações do id 71 gravado.
# Recomendações do id 72 gravado.
# Recomendações do id 73 gravado.
# Recomendações do id 74 gravado.
# Recomendações do id 75 gravado.
# Recomendações do id 76 gravado.
# Recomendações do id 78 gravado.
# Recomendações do id 79 gravado.
# Recomendações do id 80 gravado.
# Recomendações do id 82 gravado.
# Recomendações do id 83 gravado.
# Recomendações do id 84 gravado.
# Recomendações do id 85 gravado.
# Recomendações do id 86 gravado.
# Recomendações do id 88 gravado.
# Recomendações do id 89 gravado.
# Recomendações do id 90 gravado.
# Recomendações do id 91 gravado.
# Recomendações do id 93 gravado.
# Recomendações do id 95 gravado.
# Recomendações do id 96 gravado.
# Recomendações do id 97 gravado.
# Recomendações do id 98 gravado.
# Recomendações do id 99 gravado.
# Recomendações do id 100 gravado.
# Recomendações do id 101 gravado.
# Recomendações do id 102 gravado.
# Recomendações do id 103 gravado.
# Recomendações do id 104 gravado.
# Recomendações do id 105 gravado.
# Recomendações do id 106 gravado.
# Recomendações do id 107 gravado.
# Recomendações do id 108 gravado.
# Recomendações do id 109 gravado.
# Recomendações do id 110 gravado.
# Recomendações do id 111 gravado.
# Recomendações do id 112 gravado.
# Recomendações do id 113 gravado.
# Recomendações do id 115 gravado.
# Recomendações do id 116 gravado.
# Recomendações do id 117 gravado.
# Recomendações do id 119 gravado.
# Recomendações do id 121 gravado.
# Recomendações do id 122 gravado.
# Recomendações do id 123 gravado.
# Recomendações do id 124 gravado.
# Recomendações do id 125 gravado.
# Recomendações do id 128 gravado.
# Recomendações do id 129 gravado.
# Recomendações do id 131 gravado.
# Recomendações do id 132 gravado.
# Recomendações do id 135 gravado.
# Recomendações do id 136 gravado.
# Recomendações do id 137 gravado.
# Recomendações do id 140 gravado.
# Recomendações do id 141 gravado.
# Recomendações do id 142 gravado.
# Recomendações do id 143 gravado.
# Recomendações do id 144 gravado.
# Recomendações do id 148 gravado.
# Recomendações do id 151 gravado.
# Recomendações do id 152 gravado.
# Recomendações do id 153 gravado.
# Recomendações do id 154 gravado.
# Recomendações do id 155 gravado.
# Recomendações do id 156 gravado.
# Recomendações do id 159 gravado.
# Recomendações do id 160 gravado.
# Recomendações do id 161 gravado.
# Recomendações do id 162 gravado.
# Recomendações do id 164 gravado.
# Recomendações do id 165 gravado.
# Recomendações do id 166 gravado.
# Recomendações do id 167 gravado.
# Recomendações do id 168 gravado.
# Recomendações do id 169 gravado.
# Recomendações do id 171 gravado.
# Recomendações do id 174 gravado.
# Recomendações do id 176 gravado.
# Recomendações do id 177 gravado.
# Recomendações do id 178 gravado.
# Recomendações do id 179 gravado.
# Recomendações do id 181 gravado.
# Recomendações do id 182 gravado.
# Recomendações do id 183 gravado.
# Recomendações do id 184 gravado.
# Recomendações do id 185 gravado.
# Recomendações do id 186 gravado.
# Recomendações do id 187 gravado.
# Recomendações do id 188 gravado.
# Recomendações do id 190 gravado.
# Recomendações do id 191 gravado.
# Recomendações do id 193 gravado.
# Recomendações do id 195 gravado.
# Recomendações do id 197 gravado.
# Recomendações do id 198 gravado.
# Recomendações do id 199 gravado.
# Recomendações do id 200 gravado.
# Recomendações do id 201 gravado.
# Recomendações do id 202 gravado.
# Recomendações do id 203 gravado.
# Recomendações do id 204 gravado.
# Recomendações do id 209 gravado.
# Recomendações do id 210 gravado.
# Recomendações do id 211 gravado.
# Recomendações do id 212 gravado.
# Recomendações do id 213 gravado.
# Recomendações do id 215 gravado.
# Recomendações do id 216 gravado.
# Recomendações do id 217 gravado.
# Recomendações do id 219 gravado.
# Recomendações do id 220 gravado.
# Recomendações do id 221 gravado.
# Recomendações do id 222 gravado.
# Recomendações do id 223 gravado.
# Recomendações do id 224 gravado.
# Recomendações do id 225 gravado.
# Recomendações do id 226 gravado.
# Recomendações do id 227 gravado.
# Recomendações do id 229 gravado.
# Recomendações do id 230 gravado.
# Recomendações do id 232 gravado.
# Recomendações do id 233 gravado.
# Recomendações do id 234 gravado.
# Recomendações do id 235 gravado.
# Recomendações do id 236 gravado.
# Recomendações do id 238 gravado.
# Recomendações do id 239 gravado.
# Recomendações do id 240 gravado.
# Recomendações do id 241 gravado.
# Recomendações do id 243 gravado.
# Recomendações do id 244 gravado.
# Recomendações do id 246 gravado.
# Recomendações do id 247 gravado.
# Recomendações do id 248 gravado.
# Recomendações do id 249 gravado.
# Recomendações do id 250 gravado.
# Recomendações do id 251 gravado.
# Recomendações do id 252 gravado.
# Recomendações do id 253 gravado.
# Recomendações do id 254 gravado.
# Recomendações do id 256 gravado.
# Recomendações do id 260 gravado.
# Recomendações do id 261 gravado.
# Recomendações do id 263 gravado.
# Recomendações do id 264 gravado.
# Recomendações do id 265 gravado.
# Recomendações do id 266 gravado.
# Recomendações do id 267 gravado.
# Recomendações do id 268 gravado.
# Recomendações do id 273 gravado.
# Recomendações do id 274 gravado.
# Recomendações do id 275 gravado.
# Recomendações do id 276 gravado.
# Recomendações do id 279 gravado.
# Recomendações do id 280 gravado.
# Recomendações do id 282 gravado.
# Recomendações do id 284 gravado.
# Recomendações do id 285 gravado.
# Recomendações do id 286 gravado.
# Recomendações do id 287 gravado.
# Recomendações do id 288 gravado.
# Recomendações do id 290 gravado.
# Recomendações do id 291 gravado.
# Recomendações do id 292 gravado.
# Recomendações do id 294 gravado.
# Recomendações do id 295 gravado.
# Recomendações do id 296 gravado.
# Recomendações do id 297 gravado.
# Recomendações do id 298 gravado.
# Recomendações do id 300 gravado.
# Recomendações do id 301 gravado.
# Recomendações do id 302 gravado.
# Recomendações do id 303 gravado.
# Recomendações do id 304 gravado.
# Recomendações do id 305 gravado.
# Recomendações do id 306 gravado.
# Recomendações do id 307 gravado.
# Recomendações do id 308 gravado.
# Recomendações do id 309 gravado.
# Recomendações do id 310 gravado.
# Recomendações do id 312 gravado.
# Recomendações do id 313 gravado.
# Recomendações do id 314 gravado.
# Recomendações do id 317 gravado.
# Recomendações do id 318 gravado.
# Recomendações do id 319 gravado.
# Recomendações do id 321 gravado.
# Recomendações do id 322 gravado.
# Recomendações do id 323 gravado.
# Recomendações do id 325 gravado.
# Recomendações do id 326 gravado.
# Recomendações do id 327 gravado.
# Recomendações do id 328 gravado.
# Recomendações do id 330 gravado.
# Recomendações do id 331 gravado.
# Recomendações do id 332 gravado.
# Recomendações do id 334 gravado.
# Recomendações do id 336 gravado.
# Recomendações do id 337 gravado.
# Recomendações do id 339 gravado.
# Recomendações do id 340 gravado.
# Recomendações do id 341 gravado.
# Recomendações do id 343 gravado.
# Recomendações do id 344 gravado.
# Recomendações do id 345 gravado.
# Recomendações do id 346 gravado.
# Recomendações do id 347 gravado.
# Recomendações do id 348 gravado.
# Recomendações do id 349 gravado.
# Recomendações do id 351 gravado.
# Recomendações do id 352 gravado.
# Recomendações do id 353 gravado.
# Recomendações do id 354 gravado.
# Recomendações do id 356 gravado.
# Recomendações do id 357 gravado.
# Recomendações do id 358 gravado.
# Recomendações do id 359 gravado.
# Recomendações do id 361 gravado.
# Recomendações do id 362 gravado.
# Recomendações do id 365 gravado.
# Recomendações do id 366 gravado.
# Recomendações do id 367 gravado.
# Recomendações do id 368 gravado.
# Recomendações do id 369 gravado.
# Recomendações do id 370 gravado.
# Recomendações do id 371 gravado.
# Recomendações do id 372 gravado.
# Recomendações do id 373 gravado.
# Recomendações do id 375 gravado.
# Recomendações do id 376 gravado.
# Recomendações do id 377 gravado.
# Recomendações do id 378 gravado.
# Recomendações do id 380 gravado.
# Recomendações do id 381 gravado.
# Recomendações do id 382 gravado.
# Recomendações do id 383 gravado.
# Recomendações do id 384 gravado.
# Recomendações do id 385 gravado.
# Recomendações do id 387 gravado.
# Recomendações do id 389 gravado.
# Recomendações do id 390 gravado.
# Recomendações do id 391 gravado.
# Recomendações do id 393 gravado.
# Recomendações do id 398 gravado.
# Recomendações do id 399 gravado.
# Recomendações do id 400 gravado.
# Recomendações do id 401 gravado.
# Recomendações do id 402 gravado.
# Recomendações do id 404 gravado.
# Recomendações do id 405 gravado.
# Recomendações do id 408 gravado.
# Recomendações do id 409 gravado.
# Recomendações do id 410 gravado.
# Recomendações do id 411 gravado.
# Recomendações do id 412 gravado.
# Recomendações do id 413 gravado.
# Recomendações do id 414 gravado.
# Recomendações do id 415 gravado.
# Recomendações do id 416 gravado.
# Recomendações do id 417 gravado.
# Recomendações do id 418 gravado.
# Recomendações do id 419 gravado.
# Recomendações do id 420 gravado.
# Recomendações do id 421 gravado.
# Recomendações do id 422 gravado.
# Recomendações do id 424 gravado.
# Recomendações do id 425 gravado.
# Recomendações do id 426 gravado.
# Recomendações do id 427 gravado.
# Recomendações do id 428 gravado.
# Recomendações do id 429 gravado.
# Recomendações do id 430 gravado.
# Recomendações do id 432 gravado.
# Recomendações do id 434 gravado.
# Recomendações do id 435 gravado.
# Recomendações do id 436 gravado.
# Recomendações do id 437 gravado.
# Recomendações do id 438 gravado.
# Recomendações do id 440 gravado.
# Recomendações do id 441 gravado.
# Recomendações do id 443 gravado.
# Recomendações do id 444 gravado.
# Recomendações do id 445 gravado.
# Recomendações do id 446 gravado.
# Recomendações do id 447 gravado.
# Recomendações do id 448 gravado.
# Recomendações do id 450 gravado.
# Recomendações do id 451 gravado.
# Recomendações do id 452 gravado.
# Recomendações do id 453 gravado.
# Recomendações do id 454 gravado.
# Recomendações do id 455 gravado.
# Recomendações do id 456 gravado.
# Recomendações do id 457 gravado.
# Recomendações do id 458 gravado.
# Recomendações do id 459 gravado.
# Recomendações do id 460 gravado.
# Recomendações do id 462 gravado.
# Recomendações do id 464 gravado.
# Recomendações do id 465 gravado.
# Recomendações do id 466 gravado.
# Recomendações do id 469 gravado.
# Recomendações do id 470 gravado.
# Recomendações do id 472 gravado.
# Recomendações do id 474 gravado.
# Recomendações do id 475 gravado.
# Recomendações do id 476 gravado.
# Recomendações do id 477 gravado.
# Recomendações do id 479 gravado.
# Recomendações do id 480 gravado.
# Recomendações do id 482 gravado.
# Recomendações do id 483 gravado.
# Recomendações do id 484 gravado.
# Recomendações do id 486 gravado.
# Recomendações do id 488 gravado.
# Recomendações do id 489 gravado.
# Recomendações do id 490 gravado.
# Recomendações do id 491 gravado.
# Recomendações do id 492 gravado.
# Recomendações do id 493 gravado.
# Recomendações do id 495 gravado.
# Recomendações do id 497 gravado.
# Recomendações do id 498 gravado.
# Recomendações do id 500 gravado.
# Recomendações do id 503 gravado.
# Recomendações do id 504 gravado.
# Recomendações do id 505 gravado.
# Recomendações do id 509 gravado.
# Recomendações do id 510 gravado.
# Recomendações do id 511 gravado.
# Recomendações do id 512 gravado.
# Recomendações do id 513 gravado.
# Recomendações do id 514 gravado.
# Recomendações do id 515 gravado.
# Recomendações do id 517 gravado.
# Recomendações do id 519 gravado.
# Recomendações do id 520 gravado.
# Recomendações do id 521 gravado.
# Recomendações do id 522 gravado.
# Recomendações do id 523 gravado.
# Recomendações do id 524 gravado.
# Recomendações do id 525 gravado.
# Recomendações do id 526 gravado.
# Recomendações do id 527 gravado.
# Recomendações do id 528 gravado.
# Recomendações do id 532 gravado.
# Recomendações do id 533 gravado.
# Recomendações do id 534 gravado.
# Recomendações do id 537 gravado.
# Recomendações do id 538 gravado.
# Recomendações do id 540 gravado.
# Recomendações do id 541 gravado.
# Recomendações do id 542 gravado.
# Recomendações do id 543 gravado.
# Recomendações do id 546 gravado.
# Recomendações do id 550 gravado.
# Recomendações do id 551 gravado.
# Recomendações do id 552 gravado.
# Recomendações do id 553 gravado.
# Recomendações do id 554 gravado.
# Recomendações do id 555 gravado.
# Recomendações do id 556 gravado.
# Recomendações do id 558 gravado.
# Recomendações do id 559 gravado.
# Recomendações do id 560 gravado.
# Recomendações do id 561 gravado.
# Recomendações do id 562 gravado.
# Recomendações do id 563 gravado.
# Recomendações do id 564 gravado.
# Recomendações do id 566 gravado.
# Recomendações do id 567 gravado.
# Recomendações do id 570 gravado.
# Recomendações do id 571 gravado.
# Recomendações do id 572 gravado.
# Recomendações do id 573 gravado.
# Recomendações do id 577 gravado.
# Recomendações do id 578 gravado.
# Recomendações do id 579 gravado.
# Recomendações do id 580 gravado.
# Recomendações do id 581 gravado.
# Recomendações do id 582 gravado.
# Recomendações do id 584 gravado.
# Recomendações do id 585 gravado.
# Recomendações do id 586 gravado.
# Recomendações do id 587 gravado.
# Recomendações do id 589 gravado.
# Recomendações do id 590 gravado.
# Recomendações do id 591 gravado.
# Recomendações do id 592 gravado.
# Recomendações do id 593 gravado.
# Recomendações do id 594 gravado.
# Recomendações do id 596 gravado.
# Recomendações do id 597 gravado.
# Recomendações do id 599 gravado.
# Recomendações do id 600 gravado.
# Recomendações do id 601 gravado.
# Recomendações do id 602 gravado.
# Recomendações do id 603 gravado.
# Recomendações do id 604 gravado.
# Recomendações do id 605 gravado.
# Recomendações do id 606 gravado.
# Recomendações do id 607 gravado.
# Recomendações do id 608 gravado.
# Recomendações do id 610 gravado.
# Recomendações do id 1 gravado.
# Recomendações do id 4 gravado.
# Recomendações do id 5 gravado.
# Recomendações do id 6 gravado.
# Recomendações do id 7 gravado.
# Recomendações do id 8 gravado.
# Recomendações do id 9 gravado.
# Recomendações do id 10 gravado.
# Recomendações do id 11 gravado.
# Recomendações do id 12 gravado.
# Recomendações do id 14 gravado.
# Recomendações do id 15 gravado.
# Recomendações do id 16 gravado.
# Recomendações do id 17 gravado.
# Recomendações do id 18 gravado.
# Recomendações do id 19 gravado.
# Recomendações do id 20 gravado.
# Recomendações do id 21 gravado.
# Recomendações do id 22 gravado.
# Recomendações do id 23 gravado.
# Recomendações do id 24 gravado.
# Recomendações do id 25 gravado.
# Recomendações do id 27 gravado.
# Recomendações do id 28 gravado.
# Recomendações do id 29 gravado.
# Recomendações do id 30 gravado.
# Recomendações do id 31 gravado.
# Recomendações do id 32 gravado.
# Recomendações do id 33 gravado.
# Recomendações do id 34 gravado.
# Recomendações do id 38 gravado.
# Recomendações do id 39 gravado.
# Recomendações do id 40 gravado.
# Recomendações do id 41 gravado.
# Recomendações do id 42 gravado.
# Recomendações do id 43 gravado.
# Recomendações do id 44 gravado.
# Recomendações do id 45 gravado.
# Recomendações do id 46 gravado.
# Recomendações do id 47 gravado.
# Recomendações do id 48 gravado.
# Recomendações do id 49 gravado.
# Recomendações do id 50 gravado.
# Recomendações do id 51 gravado.
# Recomendações do id 52 gravado.
# Recomendações do id 53 gravado.
# Recomendações do id 56 gravado.
# Recomendações do id 57 gravado.
# Recomendações do id 58 gravado.
# Recomendações do id 59 gravado.
# Recomendações do id 61 gravado.
# Recomendações do id 62 gravado.
# Recomendações do id 63 gravado.
# Recomendações do id 64 gravado.
# Recomendações do id 65 gravado.
# Recomendações do id 66 gravado.
# Recomendações do id 67 gravado.
# Recomendações do id 68 gravado.
# Recomendações do id 69 gravado.
# Recomendações do id 70 gravado.
# Recomendações do id 71 gravado.
# Recomendações do id 72 gravado.
# Recomendações do id 73 gravado.
# Recomendações do id 74 gravado.
# Recomendações do id 75 gravado.
# Recomendações do id 76 gravado.
# Recomendações do id 78 gravado.
# Recomendações do id 79 gravado.
# Recomendações do id 80 gravado.
# Recomendações do id 82 gravado.
# Recomendações do id 83 gravado.
# Recomendações do id 84 gravado.
# Recomendações do id 85 gravado.
# Recomendações do id 86 gravado.
# Recomendações do id 88 gravado.
# Recomendações do id 89 gravado.
# Recomendações do id 90 gravado.
# Recomendações do id 91 gravado.
# Recomendações do id 93 gravado.
# Recomendações do id 95 gravado.
# Recomendações do id 96 gravado.
# Recomendações do id 97 gravado.
# Recomendações do id 98 gravado.
# Recomendações do id 99 gravado.
# Recomendações do id 100 gravado.
# Recomendações do id 101 gravado.
# Recomendações do id 102 gravado.
# Recomendações do id 103 gravado.
# Recomendações do id 104 gravado.
# Recomendações do id 105 gravado.
# Recomendações do id 106 gravado.
# Recomendações do id 107 gravado.
# Recomendações do id 108 gravado.
# Recomendações do id 109 gravado.
# Recomendações do id 110 gravado.
# Recomendações do id 111 gravado.
# Recomendações do id 112 gravado.
# Recomendações do id 113 gravado.
# Recomendações do id 115 gravado.
# Recomendações do id 116 gravado.
# Recomendações do id 117 gravado.
# Recomendações do id 119 gravado.
# Recomendações do id 121 gravado.
# Recomendações do id 122 gravado.
# Recomendações do id 123 gravado.
# Recomendações do id 124 gravado.
# Recomendações do id 125 gravado.
# Recomendações do id 128 gravado.
# Recomendações do id 129 gravado.
# Recomendações do id 131 gravado.
# Recomendações do id 132 gravado.
# Recomendações do id 135 gravado.
# Recomendações do id 136 gravado.
# Recomendações do id 137 gravado.
# Recomendações do id 140 gravado.
# Recomendações do id 141 gravado.
# Recomendações do id 142 gravado.
# Recomendações do id 143 gravado.
# Recomendações do id 144 gravado.
# Recomendações do id 148 gravado.
# Recomendações do id 151 gravado.
# Recomendações do id 152 gravado.
# Recomendações do id 153 gravado.
# Recomendações do id 154 gravado.
# Recomendações do id 155 gravado.
# Recomendações do id 156 gravado.
# Recomendações do id 159 gravado.
# Recomendações do id 160 gravado.
# Recomendações do id 161 gravado.
# Recomendações do id 162 gravado.
# Recomendações do id 164 gravado.
# Recomendações do id 165 gravado.
# Recomendações do id 166 gravado.
# Recomendações do id 167 gravado.
# Recomendações do id 168 gravado.
# Recomendações do id 169 gravado.
# Recomendações do id 171 gravado.
# Recomendações do id 174 gravado.
# Recomendações do id 176 gravado.
# Recomendações do id 177 gravado.
# Recomendações do id 178 gravado.
# Recomendações do id 179 gravado.
# Recomendações do id 181 gravado.
# Recomendações do id 182 gravado.
# Recomendações do id 183 gravado.
# Recomendações do id 184 gravado.
# Recomendações do id 185 gravado.
# Recomendações do id 186 gravado.
# Recomendações do id 187 gravado.
# Recomendações do id 188 gravado.
# Recomendações do id 190 gravado.
# Recomendações do id 191 gravado.
# Recomendações do id 193 gravado.
# Recomendações do id 195 gravado.
# Recomendações do id 197 gravado.
# Recomendações do id 198 gravado.
# Recomendações do id 199 gravado.
# Recomendações do id 200 gravado.
# Recomendações do id 201 gravado.
# Recomendações do id 202 gravado.
# Recomendações do id 203 gravado.
# Recomendações do id 204 gravado.
# Recomendações do id 209 gravado.
# Recomendações do id 210 gravado.
# Recomendações do id 211 gravado.
# Recomendações do id 212 gravado.
# Recomendações do id 213 gravado.
# Recomendações do id 215 gravado.
# Recomendações do id 216 gravado.
# Recomendações do id 217 gravado.
# Recomendações do id 219 gravado.
# Recomendações do id 220 gravado.
# Recomendações do id 221 gravado.
# Recomendações do id 222 gravado.
# Recomendações do id 223 gravado.
# Recomendações do id 224 gravado.
# Recomendações do id 225 gravado.
# Recomendações do id 226 gravado.
# Recomendações do id 227 gravado.
# Recomendações do id 229 gravado.
# Recomendações do id 230 gravado.
# Recomendações do id 232 gravado.
# Recomendações do id 233 gravado.
# Recomendações do id 234 gravado.
# Recomendações do id 235 gravado.
# Recomendações do id 236 gravado.
# Recomendações do id 238 gravado.
# Recomendações do id 239 gravado.
# Recomendações do id 240 gravado.
# Recomendações do id 241 gravado.
# Recomendações do id 243 gravado.
# Recomendações do id 244 gravado.
# Recomendações do id 246 gravado.
# Recomendações do id 247 gravado.
# Recomendações do id 248 gravado.
# Recomendações do id 249 gravado.
# Recomendações do id 250 gravado.
# Recomendações do id 251 gravado.
# Recomendações do id 252 gravado.
# Recomendações do id 253 gravado.
# Recomendações do id 254 gravado.
# Recomendações do id 256 gravado.
# Recomendações do id 260 gravado.
# Recomendações do id 261 gravado.
# Recomendações do id 263 gravado.
# Recomendações do id 264 gravado.
# Recomendações do id 265 gravado.
# Recomendações do id 266 gravado.
# Recomendações do id 267 gravado.
# Recomendações do id 268 gravado.
# Recomendações do id 273 gravado.
# Recomendações do id 274 gravado.
# Recomendações do id 275 gravado.
# Recomendações do id 276 gravado.
# Recomendações do id 279 gravado.
# Recomendações do id 280 gravado.
# Recomendações do id 282 gravado.
# Recomendações do id 284 gravado.
# Recomendações do id 285 gravado.
# Recomendações do id 286 gravado.
# Recomendações do id 287 gravado.
# Recomendações do id 288 gravado.
# Recomendações do id 290 gravado.
# Recomendações do id 291 gravado.
# Recomendações do id 292 gravado.
# Recomendações do id 294 gravado.
# Recomendações do id 295 gravado.
# Recomendações do id 296 gravado.
# Recomendações do id 297 gravado.
# Recomendações do id 298 gravado.
# Recomendações do id 300 gravado.
# Recomendações do id 301 gravado.
# Recomendações do id 302 gravado.
# Recomendações do id 303 gravado.
# Recomendações do id 304 gravado.
# Recomendações do id 305 gravado.
# Recomendações do id 306 gravado.
# Recomendações do id 307 gravado.
# Recomendações do id 308 gravado.
# Recomendações do id 309 gravado.
# Recomendações do id 310 gravado.
# Recomendações do id 312 gravado.
# Recomendações do id 313 gravado.
# Recomendações do id 314 gravado.
# Recomendações do id 317 gravado.
# Recomendações do id 318 gravado.
# Recomendações do id 319 gravado.
# Recomendações do id 321 gravado.
# Recomendações do id 322 gravado.
# Recomendações do id 323 gravado.
# Recomendações do id 325 gravado.
# Recomendações do id 326 gravado.
# Recomendações do id 327 gravado.
# Recomendações do id 328 gravado.
# Recomendações do id 330 gravado.
# Recomendações do id 331 gravado.
# Recomendações do id 332 gravado.
# Recomendações do id 334 gravado.
# Recomendações do id 336 gravado.
# Recomendações do id 337 gravado.
# Recomendações do id 339 gravado.
# Recomendações do id 340 gravado.
# Recomendações do id 341 gravado.
# Recomendações do id 343 gravado.
# Recomendações do id 344 gravado.
# Recomendações do id 345 gravado.
# Recomendações do id 346 gravado.
# Recomendações do id 347 gravado.
# Recomendações do id 348 gravado.
# Recomendações do id 349 gravado.
# Recomendações do id 351 gravado.
# Recomendações do id 352 gravado.
# Recomendações do id 353 gravado.
# Recomendações do id 354 gravado.
# Recomendações do id 356 gravado.
# Recomendações do id 357 gravado.
# Recomendações do id 358 gravado.
# Recomendações do id 359 gravado.
# Recomendações do id 361 gravado.
# Recomendações do id 362 gravado.
# Recomendações do id 365 gravado.
# Recomendações do id 366 gravado.
# Recomendações do id 367 gravado.
# Recomendações do id 368 gravado.
# Recomendações do id 369 gravado.
# Recomendações do id 370 gravado.
# Recomendações do id 371 gravado.
# Recomendações do id 372 gravado.
# Recomendações do id 373 gravado.
# Recomendações do id 375 gravado.
# Recomendações do id 376 gravado.
# Recomendações do id 377 gravado.
# Recomendações do id 378 gravado.
# Recomendações do id 380 gravado.
# Recomendações do id 381 gravado.
# Recomendações do id 382 gravado.
# Recomendações do id 383 gravado.
# Recomendações do id 384 gravado.
# Recomendações do id 385 gravado.
# Recomendações do id 387 gravado.
# Recomendações do id 389 gravado.
# Recomendações do id 390 gravado.
# Recomendações do id 391 gravado.
# Recomendações do id 393 gravado.
# Recomendações do id 398 gravado.
# Recomendações do id 399 gravado.
# Recomendações do id 400 gravado.
# Recomendações do id 401 gravado.
# Recomendações do id 402 gravado.
# Recomendações do id 404 gravado.
# Recomendações do id 405 gravado.
# Recomendações do id 408 gravado.
# Recomendações do id 409 gravado.
# Recomendações do id 410 gravado.
# Recomendações do id 411 gravado.
# Recomendações do id 412 gravado.
# Recomendações do id 413 gravado.
# Recomendações do id 414 gravado.
# Recomendações do id 415 gravado.
# Recomendações do id 416 gravado.
# Recomendações do id 417 gravado.
# Recomendações do id 418 gravado.
# Recomendações do id 419 gravado.
# Recomendações do id 420 gravado.
# Recomendações do id 421 gravado.
# Recomendações do id 422 gravado.
# Recomendações do id 424 gravado.
# Recomendações do id 425 gravado.
# Recomendações do id 426 gravado.
# Recomendações do id 427 gravado.
# Recomendações do id 428 gravado.
# Recomendações do id 429 gravado.
# Recomendações do id 430 gravado.
# Recomendações do id 432 gravado.
# Recomendações do id 434 gravado.
# Recomendações do id 435 gravado.
# Recomendações do id 436 gravado.
# Recomendações do id 437 gravado.
# Recomendações do id 438 gravado.
# Recomendações do id 440 gravado.
# Recomendações do id 441 gravado.
# Recomendações do id 443 gravado.
# Recomendações do id 444 gravado.
# Recomendações do id 445 gravado.
# Recomendações do id 446 gravado.
# Recomendações do id 447 gravado.
# Recomendações do id 448 gravado.
# Recomendações do id 450 gravado.
# Recomendações do id 451 gravado.
# Recomendações do id 452 gravado.
# Recomendações do id 453 gravado.
# Recomendações do id 454 gravado.
# Recomendações do id 455 gravado.
# Recomendações do id 456 gravado.
# Recomendações do id 457 gravado.
# Recomendações do id 458 gravado.
# Recomendações do id 459 gravado.
# Recomendações do id 460 gravado.
# Recomendações do id 462 gravado.
# Recomendações do id 464 gravado.
# Recomendações do id 465 gravado.
# Recomendações do id 466 gravado.
# Recomendações do id 469 gravado.
# Recomendações do id 470 gravado.
# Recomendações do id 472 gravado.
# Recomendações do id 474 gravado.
# Recomendações do id 475 gravado.
# Recomendações do id 476 gravado.
# Recomendações do id 477 gravado.
# Recomendações do id 479 gravado.
# Recomendações do id 480 gravado.
# Recomendações do id 482 gravado.
# Recomendações do id 483 gravado.
# Recomendações do id 484 gravado.
# Recomendações do id 486 gravado.
# Recomendações do id 488 gravado.
# Recomendações do id 489 gravado.
# Recomendações do id 490 gravado.
# Recomendações do id 491 gravado.
# Recomendações do id 492 gravado.
# Recomendações do id 493 gravado.
# Recomendações do id 495 gravado.
# Recomendações do id 497 gravado.
# Recomendações do id 498 gravado.
# Recomendações do id 500 gravado.
# Recomendações do id 503 gravado.
# Recomendações do id 504 gravado.
# Recomendações do id 505 gravado.
# Recomendações do id 509 gravado.
# Recomendações do id 510 gravado.
# Recomendações do id 511 gravado.
# Recomendações do id 512 gravado.
# Recomendações do id 513 gravado.
# Recomendações do id 514 gravado.
# Recomendações do id 515 gravado.
# Recomendações do id 517 gravado.
# Recomendações do id 519 gravado.
# Recomendações do id 520 gravado.
# Recomendações do id 521 gravado.
# Recomendações do id 522 gravado.
# Recomendações do id 523 gravado.
# Recomendações do id 524 gravado.
# Recomendações do id 525 gravado.
# Recomendações do id 526 gravado.
# Recomendações do id 527 gravado.
# Recomendações do id 528 gravado.
# Recomendações do id 532 gravado.
# Recomendações do id 533 gravado.
# Recomendações do id 534 gravado.
# Recomendações do id 537 gravado.
# Recomendações do id 538 gravado.
# Recomendações do id 540 gravado.
# Recomendações do id 541 gravado.
# Recomendações do id 542 gravado.
# Recomendações do id 543 gravado.
# Recomendações do id 546 gravado.
# Recomendações do id 550 gravado.
# Recomendações do id 551 gravado.
# Recomendações do id 552 gravado.
# Recomendações do id 553 gravado.
# Recomendações do id 554 gravado.
# Recomendações do id 555 gravado.
# Recomendações do id 556 gravado.
# Recomendações do id 558 gravado.
# Recomendações do id 559 gravado.
# Recomendações do id 560 gravado.
# Recomendações do id 561 gravado.
# Recomendações do id 562 gravado.
# Recomendações do id 563 gravado.
# Recomendações do id 564 gravado.
# Recomendações do id 566 gravado.
# Recomendações do id 567 gravado.
# Recomendações do id 570 gravado.
# Recomendações do id 571 gravado.
# Recomendações do id 572 gravado.
# Recomendações do id 573 gravado.
# Recomendações do id 577 gravado.
# Recomendações do id 578 gravado.
# Recomendações do id 579 gravado.
# Recomendações do id 580 gravado.
# Recomendações do id 581 gravado.
# Recomendações do id 582 gravado.
# Recomendações do id 584 gravado.
# Recomendações do id 585 gravado.
# Recomendações do id 586 gravado.
# Recomendações do id 587 gravado.
# Recomendações do id 589 gravado.
# Recomendações do id 590 gravado.
# Recomendações do id 591 gravado.
# Recomendações do id 592 gravado.
# Recomendações do id 593 gravado.
# Recomendações do id 594 gravado.
# Recomendações do id 596 gravado.
# Recomendações do id 597 gravado.
# Recomendações do id 599 gravado.
# Recomendações do id 600 gravado.
# Recomendações do id 601 gravado.
# Recomendações do id 602 gravado.
# Recomendações do id 603 gravado.
# Recomendações do id 604 gravado.
# Recomendações do id 605 gravado.
# Recomendações do id 606 gravado.
# Recomendações do id 607 gravado.
# Recomendações do id 608 gravado.
# Recomendações do id 610 gravado.
# Recomendações do id 1 gravado.
# Recomendações do id 4 gravado.
# Recomendações do id 5 gravado.
# Recomendações do id 6 gravado.
# Recomendações do id 7 gravado.
# Recomendações do id 8 gravado.
# Recomendações do id 9 gravado.
# Recomendações do id 10 gravado.
# Recomendações do id 11 gravado.
# Recomendações do id 12 gravado.
# Recomendações do id 14 gravado.
# Recomendações do id 15 gravado.
# Recomendações do id 16 gravado.
# Recomendações do id 17 gravado.
# Recomendações do id 18 gravado.
# Recomendações do id 19 gravado.
# Recomendações do id 20 gravado.
# Recomendações do id 21 gravado.
# Recomendações do id 22 gravado.
# Recomendações do id 23 gravado.
# Recomendações do id 24 gravado.
# Recomendações do id 25 gravado.
# Recomendações do id 27 gravado.
# Recomendações do id 28 gravado.
# Recomendações do id 29 gravado.
# Recomendações do id 30 gravado.
# Recomendações do id 31 gravado.
# Recomendações do id 32 gravado.
# Recomendações do id 33 gravado.
# Recomendações do id 34 gravado.
# Recomendações do id 38 gravado.
# Recomendações do id 39 gravado.
# Recomendações do id 40 gravado.
# Recomendações do id 41 gravado.
# Recomendações do id 42 gravado.
# Recomendações do id 43 gravado.
# Recomendações do id 44 gravado.
# Recomendações do id 45 gravado.
# Recomendações do id 46 gravado.
# Recomendações do id 47 gravado.
# Recomendações do id 48 gravado.
# Recomendações do id 49 gravado.
# Recomendações do id 50 gravado.
# Recomendações do id 51 gravado.
# Recomendações do id 52 gravado.
# Recomendações do id 53 gravado.
# Recomendações do id 56 gravado.
# Recomendações do id 57 gravado.
# Recomendações do id 58 gravado.
# Recomendações do id 59 gravado.
# Recomendações do id 61 gravado.
# Recomendações do id 62 gravado.
# Recomendações do id 63 gravado.
# Recomendações do id 64 gravado.
# Recomendações do id 65 gravado.
# Recomendações do id 66 gravado.
# Recomendações do id 67 gravado.
# Recomendações do id 68 gravado.
# Recomendações do id 69 gravado.
# Recomendações do id 70 gravado.
# Recomendações do id 71 gravado.
# Recomendações do id 72 gravado.
# Recomendações do id 73 gravado.
# Recomendações do id 74 gravado.
# Recomendações do id 75 gravado.
# Recomendações do id 76 gravado.
# Recomendações do id 78 gravado.
# Recomendações do id 79 gravado.
# Recomendações do id 80 gravado.
# Recomendações do id 82 gravado.
# ...
# Recomendações do id 585 gravado.
# Recomendações do id 586 gravado.
# Recomendações do id 587 gravado.
# Recomendações do id 589 gravado.
# Recomendações do id 590 gravado.
# Recomendações do id 591 gravado.
# Recomendações do id 592 gravado.
# Recomendações do id 593 gravado.
# Recomendações do id 594 gravado.
# Recomendações do id 596 gravado.
# Recomendações do id 597 gravado.
# Recomendações do id 599 gravado.
# Recomendações do id 600 gravado.
# Recomendações do id 601 gravado.
# Recomendações do id 602 gravado.
# Recomendações do id 603 gravado.
# Recomendações do id 604 gravado.
# Recomendações do id 605 gravado.
# Recomendações do id 606 gravado.
# Recomendações do id 607 gravado.
# Recomendações do id 608 gravado.
# Recomendações do id 610 gravado.
# Recomendações do id 1 gravado.
# Recomendações do id 4 gravado.
# Recomendações do id 5 gravado.
# Recomendações do id 6 gravado.
# Recomendações do id 7 gravado.
# Recomendações do id 8 gravado.
# Recomendações do id 9 gravado.
# Recomendações do id 10 gravado.
# Recomendações do id 11 gravado.
# Recomendações do id 12 gravado.
# Recomendações do id 14 gravado.
# Recomendações do id 15 gravado.
# Recomendações do id 16 gravado.
# Recomendações do id 17 gravado.
# Recomendações do id 18 gravado.
# Recomendações do id 19 gravado.
# Recomendações do id 20 gravado.
# Recomendações do id 21 gravado.
# Recomendações do id 22 gravado.
# Recomendações do id 23 gravado.
# Recomendações do id 24 gravado.
# Recomendações do id 25 gravado.
# Recomendações do id 27 gravado.
# Recomendações do id 28 gravado.
# Recomendações do id 29 gravado.
# Recomendações do id 30 gravado.
# Recomendações do id 31 gravado.
# Recomendações do id 32 gravado.
# Recomendações do id 33 gravado.
# Recomendações do id 34 gravado.
# Recomendações do id 38 gravado.
# Recomendações do id 39 gravado.
# Recomendações do id 40 gravado.
# Recomendações do id 41 gravado.
# Recomendações do id 42 gravado.
# Recomendações do id 43 gravado.
# Recomendações do id 44 gravado.
# Recomendações do id 45 gravado.
# Recomendações do id 46 gravado.
# Recomendações do id 47 gravado.
# Recomendações do id 48 gravado.
# Recomendações do id 49 gravado.
# Recomendações do id 50 gravado.
# Recomendações do id 51 gravado.
# Recomendações do id 52 gravado.
# Recomendações do id 53 gravado.
# Recomendações do id 56 gravado.
# Recomendações do id 57 gravado.
# Recomendações do id 58 gravado.
# Recomendações do id 59 gravado.
# Recomendações do id 61 gravado.
# Recomendações do id 62 gravado.
# Recomendações do id 63 gravado.
# Recomendações do id 64 gravado.
# Recomendações do id 65 gravado.
# Recomendações do id 66 gravado.
# Recomendações do id 67 gravado.
# Recomendações do id 68 gravado.
# Recomendações do id 69 gravado.
# Recomendações do id 70 gravado.
# Recomendações do id 71 gravado.
# Recomendações do id 72 gravado.
# Recomendações do id 73 gravado.
# Recomendações do id 74 gravado.
# Recomendações do id 75 gravado.
# Recomendações do id 76 gravado.
# Recomendações do id 78 gravado.
# Recomendações do id 79 gravado.
# Recomendações do id 80 gravado.
# Recomendações do id 82 gravado.
# Recomendações do id 83 gravado.
# Recomendações do id 84 gravado.
# Recomendações do id 85 gravado.
# Recomendações do id 86 gravado.
# Recomendações do id 88 gravado.
# Recomendações do id 89 gravado.
# Recomendações do id 90 gravado.
# Recomendações do id 91 gravado.
# Recomendações do id 93 gravado.
# Recomendações do id 95 gravado.
# Recomendações do id 96 gravado.
# Recomendações do id 97 gravado.
# Recomendações do id 98 gravado.
# Recomendações do id 99 gravado.
# Recomendações do id 100 gravado.
# Recomendações do id 101 gravado.
# Recomendações do id 102 gravado.
# Recomendações do id 103 gravado.
# Recomendações do id 104 gravado.
# Recomendações do id 105 gravado.
# Recomendações do id 106 gravado.
# Recomendações do id 107 gravado.
# Recomendações do id 108 gravado.
# Recomendações do id 109 gravado.
# Recomendações do id 110 gravado.
# Recomendações do id 111 gravado.
# Recomendações do id 112 gravado.
# Recomendações do id 113 gravado.
# Recomendações do id 115 gravado.
# Recomendações do id 116 gravado.
# Recomendações do id 117 gravado.
# Recomendações do id 119 gravado.
# Recomendações do id 121 gravado.
# Recomendações do id 122 gravado.
# Recomendações do id 123 gravado.
# Recomendações do id 124 gravado.
# Recomendações do id 125 gravado.
# Recomendações do id 128 gravado.
# Recomendações do id 129 gravado.
# Recomendações do id 131 gravado.
# Recomendações do id 132 gravado.
# Recomendações do id 135 gravado.
# Recomendações do id 136 gravado.
# Recomendações do id 137 gravado.
# Recomendações do id 140 gravado.
# Recomendações do id 141 gravado.
# Recomendações do id 142 gravado.
# Recomendações do id 143 gravado.
# Recomendações do id 144 gravado.
# Recomendações do id 148 gravado.
# Recomendações do id 151 gravado.
# Recomendações do id 152 gravado.
# Recomendações do id 153 gravado.
# Recomendações do id 154 gravado.
# Recomendações do id 155 gravado.
# Recomendações do id 156 gravado.
# Recomendações do id 159 gravado.
# Recomendações do id 160 gravado.
# Recomendações do id 161 gravado.
# Recomendações do id 162 gravado.
# Recomendações do id 164 gravado.
# Recomendações do id 165 gravado.
# Recomendações do id 166 gravado.
# Recomendações do id 167 gravado.
# Recomendações do id 168 gravado.
# Recomendações do id 169 gravado.
# Recomendações do id 171 gravado.
# Recomendações do id 174 gravado.
# Recomendações do id 176 gravado.
# Recomendações do id 177 gravado.
# Recomendações do id 178 gravado.
# Recomendações do id 179 gravado.
# Recomendações do id 181 gravado.
# Recomendações do id 182 gravado.
# Recomendações do id 183 gravado.
# Recomendações do id 184 gravado.
# Recomendações do id 185 gravado.
# Recomendações do id 186 gravado.
# Recomendações do id 187 gravado.
# Recomendações do id 188 gravado.
# Recomendações do id 190 gravado.
# Recomendações do id 191 gravado.
# Recomendações do id 193 gravado.
# Recomendações do id 195 gravado.
# Recomendações do id 197 gravado.
# Recomendações do id 198 gravado.
# Recomendações do id 199 gravado.
# Recomendações do id 200 gravado.
# Recomendações do id 201 gravado.
# Recomendações do id 202 gravado.
# Recomendações do id 203 gravado.
# Recomendações do id 204 gravado.
# Recomendações do id 209 gravado.
# Recomendações do id 210 gravado.
# Recomendações do id 211 gravado.
# Recomendações do id 212 gravado.
# Recomendações do id 213 gravado.
# Recomendações do id 215 gravado.
# Recomendações do id 216 gravado.
# Recomendações do id 217 gravado.
# Recomendações do id 219 gravado.
# Recomendações do id 220 gravado.
# Recomendações do id 221 gravado.
# Recomendações do id 222 gravado.
# Recomendações do id 223 gravado.
# Recomendações do id 224 gravado.
# Recomendações do id 225 gravado.
# Recomendações do id 226 gravado.
# Recomendações do id 227 gravado.
# Recomendações do id 229 gravado.
# Recomendações do id 230 gravado.
# Recomendações do id 232 gravado.
# Recomendações do id 233 gravado.
# Recomendações do id 234 gravado.
# Recomendações do id 235 gravado.
# Recomendações do id 236 gravado.
# Recomendações do id 238 gravado.
# Recomendações do id 239 gravado.
# Recomendações do id 240 gravado.
# Recomendações do id 241 gravado.
# Recomendações do id 243 gravado.
# Recomendações do id 244 gravado.
# Recomendações do id 246 gravado.
# Recomendações do id 247 gravado.
# Recomendações do id 248 gravado.
# Recomendações do id 249 gravado.
# Recomendações do id 250 gravado.
# Recomendações do id 251 gravado.
# Recomendações do id 252 gravado.
# Recomendações do id 253 gravado.
# Recomendações do id 254 gravado.
# Recomendações do id 256 gravado.
# Recomendações do id 260 gravado.
# Recomendações do id 261 gravado.
# Recomendações do id 263 gravado.
# Recomendações do id 264 gravado.
# Recomendações do id 265 gravado.
# Recomendações do id 266 gravado.
# Recomendações do id 267 gravado.
# Recomendações do id 268 gravado.
# Recomendações do id 273 gravado.
# Recomendações do id 274 gravado.
# Recomendações do id 275 gravado.
# Recomendações do id 276 gravado.
# Recomendações do id 279 gravado.
# Recomendações do id 280 gravado.
# Recomendações do id 282 gravado.
# Recomendações do id 284 gravado.
# Recomendações do id 285 gravado.
# Recomendações do id 286 gravado.
# Recomendações do id 287 gravado.
# Recomendações do id 288 gravado.
# Recomendações do id 290 gravado.
# Recomendações do id 291 gravado.
# Recomendações do id 292 gravado.
# Recomendações do id 294 gravado.
# Recomendações do id 295 gravado.
# Recomendações do id 296 gravado.
# Recomendações do id 297 gravado.
# Recomendações do id 298 gravado.
# Recomendações do id 300 gravado.
# Recomendações do id 301 gravado.
# Recomendações do id 302 gravado.
# Recomendações do id 303 gravado.
# Recomendações do id 304 gravado.
# Recomendações do id 305 gravado.
# Recomendações do id 306 gravado.
# Recomendações do id 307 gravado.
# Recomendações do id 308 gravado.
# Recomendações do id 309 gravado.
# Recomendações do id 310 gravado.
# Recomendações do id 312 gravado.
# Recomendações do id 313 gravado.
# Recomendações do id 314 gravado.
# Recomendações do id 317 gravado.
# Recomendações do id 318 gravado.
# Recomendações do id 319 gravado.
# Recomendações do id 321 gravado.
# Recomendações do id 322 gravado.
# Recomendações do id 323 gravado.
# Recomendações do id 325 gravado.
# Recomendações do id 326 gravado.
# Recomendações do id 327 gravado.
# Recomendações do id 328 gravado.
# Recomendações do id 330 gravado.
# Recomendações do id 331 gravado.
# Recomendações do id 332 gravado.
# Recomendações do id 334 gravado.
# Recomendações do id 336 gravado.
# Recomendações do id 337 gravado.
# Recomendações do id 339 gravado.
# Recomendações do id 340 gravado.
# Recomendações do id 341 gravado.
# Recomendações do id 343 gravado.
# Recomendações do id 344 gravado.
# Recomendações do id 345 gravado.
# Recomendações do id 346 gravado.
# Recomendações do id 347 gravado.
# Recomendações do id 348 gravado.
# Recomendações do id 349 gravado.
# Recomendações do id 351 gravado.
# Recomendações do id 352 gravado.
# Recomendações do id 353 gravado.
# Recomendações do id 354 gravado.
# Recomendações do id 356 gravado.
# Recomendações do id 357 gravado.
# Recomendações do id 358 gravado.
# Recomendações do id 359 gravado.
# Recomendações do id 361 gravado.
# Recomendações do id 362 gravado.
# Recomendações do id 365 gravado.
# Recomendações do id 366 gravado.
# Recomendações do id 367 gravado.
# Recomendações do id 368 gravado.
# Recomendações do id 369 gravado.
# Recomendações do id 370 gravado.
# Recomendações do id 371 gravado.
# Recomendações do id 372 gravado.
# Recomendações do id 373 gravado.
# Recomendações do id 375 gravado.
# Recomendações do id 376 gravado.
# Recomendações do id 377 gravado.
# Recomendações do id 378 gravado.
# Recomendações do id 380 gravado.
# Recomendações do id 381 gravado.
# Recomendações do id 382 gravado.
# Recomendações do id 383 gravado.
# Recomendações do id 384 gravado.
# Recomendações do id 385 gravado.
# Recomendações do id 387 gravado.
# Recomendações do id 389 gravado.
# Recomendações do id 390 gravado.
# Recomendações do id 391 gravado.
# Recomendações do id 393 gravado.
# Recomendações do id 398 gravado.
# Recomendações do id 399 gravado.
# Recomendações do id 400 gravado.
# Recomendações do id 401 gravado.
# Recomendações do id 402 gravado.
# Recomendações do id 404 gravado.
# Recomendações do id 405 gravado.
# Recomendações do id 408 gravado.
# Recomendações do id 409 gravado.
# Recomendações do id 410 gravado.
# Recomendações do id 411 gravado.
# Recomendações do id 412 gravado.
# Recomendações do id 413 gravado.
# Recomendações do id 414 gravado.
# Recomendações do id 415 gravado.
# Recomendações do id 416 gravado.
# Recomendações do id 417 gravado.
# Recomendações do id 418 gravado.
# Recomendações do id 419 gravado.
# Recomendações do id 420 gravado.
# Recomendações do id 421 gravado.
# Recomendações do id 422 gravado.
# Recomendações do id 424 gravado.
# Recomendações do id 425 gravado.
# Recomendações do id 426 gravado.
# Recomendações do id 427 gravado.
# Recomendações do id 428 gravado.
# Recomendações do id 429 gravado.
# Recomendações do id 430 gravado.
# Recomendações do id 432 gravado.
# Recomendações do id 434 gravado.
# Recomendações do id 435 gravado.
# Recomendações do id 436 gravado.
# Recomendações do id 437 gravado.
# Recomendações do id 438 gravado.
# Recomendações do id 440 gravado.
# Recomendações do id 441 gravado.
# Recomendações do id 443 gravado.
# Recomendações do id 444 gravado.
# Recomendações do id 445 gravado.
# Recomendações do id 446 gravado.
# Recomendações do id 447 gravado.
# Recomendações do id 448 gravado.
# Recomendações do id 450 gravado.
# Recomendações do id 451 gravado.
# Recomendações do id 452 gravado.
# Recomendações do id 453 gravado.
# Recomendações do id 454 gravado.
# Recomendações do id 455 gravado.
# Recomendações do id 456 gravado.
# Recomendações do id 457 gravado.
# Recomendações do id 458 gravado.
# Recomendações do id 459 gravado.
# Recomendações do id 460 gravado.
# Recomendações do id 462 gravado.
# Recomendações do id 464 gravado.
# Recomendações do id 465 gravado.
# Recomendações do id 466 gravado.
# Recomendações do id 469 gravado.
# Recomendações do id 470 gravado.
# Recomendações do id 472 gravado.
# Recomendações do id 474 gravado.
# Recomendações do id 475 gravado.
# Recomendações do id 476 gravado.
# Recomendações do id 477 gravado.
# Recomendações do id 479 gravado.
# Recomendações do id 480 gravado.
# Recomendações do id 482 gravado.
# Recomendações do id 483 gravado.
# Recomendações do id 484 gravado.
# Recomendações do id 486 gravado.
# Recomendações do id 488 gravado.
# Recomendações do id 489 gravado.
# Recomendações do id 490 gravado.
# Recomendações do id 491 gravado.
# Recomendações do id 492 gravado.
# Recomendações do id 493 gravado.
# Recomendações do id 495 gravado.
# Recomendações do id 497 gravado.
# Recomendações do id 498 gravado.
# Recomendações do id 500 gravado.
# Recomendações do id 503 gravado.
# Recomendações do id 504 gravado.
# Recomendações do id 505 gravado.
# Recomendações do id 509 gravado.
# Recomendações do id 510 gravado.
# Recomendações do id 511 gravado.
# Recomendações do id 512 gravado.
# Recomendações do id 513 gravado.
# Recomendações do id 514 gravado.
# Recomendações do id 515 gravado.
# Recomendações do id 517 gravado.
# Recomendações do id 519 gravado.
# Recomendações do id 520 gravado.
# Recomendações do id 521 gravado.
# Recomendações do id 522 gravado.
# Recomendações do id 523 gravado.
# Recomendações do id 524 gravado.
# Recomendações do id 525 gravado.
# Recomendações do id 526 gravado.
# Recomendações do id 527 gravado.
# Recomendações do id 528 gravado.
# Recomendações do id 532 gravado.
# Recomendações do id 533 gravado.
# Recomendações do id 534 gravado.
# Recomendações do id 537 gravado.
# Recomendações do id 538 gravado.
# Recomendações do id 540 gravado.
# Recomendações do id 541 gravado.
# Recomendações do id 542 gravado.
# Recomendações do id 543 gravado.
# Recomendações do id 546 gravado.
# Recomendações do id 550 gravado.
# Recomendações do id 551 gravado.
# Recomendações do id 552 gravado.
# Recomendações do id 553 gravado.
# Recomendações do id 554 gravado.
# Recomendações do id 555 gravado.
# Recomendações do id 556 gravado.
# Recomendações do id 558 gravado.
# Recomendações do id 559 gravado.
# Recomendações do id 560 gravado.
# Recomendações do id 561 gravado.
# Recomendações do id 562 gravado.
# Recomendações do id 563 gravado.
# Recomendações do id 564 gravado.
# Recomendações do id 566 gravado.
# Recomendações do id 567 gravado.
# Recomendações do id 570 gravado.
# Recomendações do id 571 gravado.
# Recomendações do id 572 gravado.
# Recomendações do id 573 gravado.
# Recomendações do id 577 gravado.
# Recomendações do id 578 gravado.
# Recomendações do id 579 gravado.
# Recomendações do id 580 gravado.
# Recomendações do id 581 gravado.
# Recomendações do id 582 gravado.
# Recomendações do id 584 gravado.
# Recomendações do id 585 gravado.
# Recomendações do id 586 gravado.
# Recomendações do id 587 gravado.
# Recomendações do id 589 gravado.
# Recomendações do id 590 gravado.
# Recomendações do id 591 gravado.
# Recomendações do id 592 gravado.
# Recomendações do id 593 gravado.
# Recomendações do id 594 gravado.
# Recomendações do id 596 gravado.
# Recomendações do id 597 gravado.
# Recomendações do id 599 gravado.
# Recomendações do id 600 gravado.
# Recomendações do id 601 gravado.
# Recomendações do id 602 gravado.
# Recomendações do id 603 gravado.
# Recomendações do id 604 gravado.
# Recomendações do id 605 gravado.
# Recomendações do id 606 gravado.
# Recomendações do id 607 gravado.
# Recomendações do id 608 gravado.
# Recomendações do id 610 gravado.
